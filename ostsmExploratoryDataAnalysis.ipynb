# %%
#Data Manipulation
import numpy as np 
import pandas as pd 
import glob
from pathlib import Path
import seaborn as sns

# %% [markdown]
#  ## Exploratory Data Analysis

# %% [markdown]
# ### Read Data

# %% [markdown]
# ### Read Training set

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
train_files = glob.glob("gdrive/MyDrive/DATASET/train*.csv")
dftrain = pd.concat((pd.read_csv(f,delimiter=';') for f in train_files))
print(dftrain)
# Out:
#                        time  P1_B2004  P1_B2016  P1_B3004   P1_B3005  \
# 0       2019-09-11 20:00:00    0.0983    1.0702  399.2321  1110.3986
# 1       2019-09-11 20:00:01    0.0983    1.0699  399.2321  1110.3986
# 2       2019-09-11 20:00:02    0.0983    1.0703  399.2321  1110.3986
# 3       2019-09-11 20:00:03    0.0983    1.0719  399.2321  1110.3986
# 4       2019-09-11 20:00:04    0.0983    1.0710  399.2321  1110.3986
# ...                     ...       ...       ...       ...        ...
# 241195  2019-11-04 14:59:55    0.1001    1.5194  395.3508  1120.8154
# 241196  2019-11-04 14:59:56    0.1001    1.5220  395.3508  1120.8154
# 241197  2019-11-04 14:59:57    0.1001    1.5235  395.3508  1120.8154
# 241198  2019-11-04 14:59:58    0.1001    1.5279  395.3508  1120.8154
# 241199  2019-11-04 14:59:59    0.1001    1.5281  395.3508  1120.8154
#
#         P1_B4002  P1_B4005  P1_B400B  P1_B4022  P1_FCV01D  ...  P4_ST_FD  \
# ...

# %%
print("The Training has {} records".format(len(dftrain)))
dftrain.head(5)
# Out:
# The Training has 550800 records
#                   time  P1_B2004  P1_B2016  P1_B3004   P1_B3005  P1_B4002  \
# 0  2019-09-11 20:00:00    0.0983    1.0702  399.2321  1110.3986      32.0
# 1  2019-09-11 20:00:01    0.0983    1.0699  399.2321  1110.3986      32.0
# 2  2019-09-11 20:00:02    0.0983    1.0703  399.2321  1110.3986      32.0
# 3  2019-09-11 20:00:03    0.0983    1.0719  399.2321  1110.3986      32.0
# 4  2019-09-11 20:00:04    0.0983    1.0710  399.2321  1110.3986      32.0
#
#    P1_B4005  P1_B400B  P1_B4022  P1_FCV01D  ...  P4_ST_FD  P4_ST_LD  P4_ST_PO  \
# 0       0.0   28.9981   35.7395        0.0  ...   -0.0004  330.6568  328.9388
# 1       0.0   29.9914   35.7388        0.0  ...   -0.0012  330.2228  329.3728
# 2       0.0   27.0122   35.7399        0.0  ...    0.0018  332.0493  329.7526
# 3       0.0   32.9705   35.7452        0.0  ...    0.0033  331.5249  331.0547
# 4       0.0   30.9843   35.7422        0.0  ...    0.0015  333.1706  331.1631
#
# ...

# %% [markdown]
# ### Read Testing set

# %%
test_files = glob.glob("gdrive/MyDrive/DATASET/test*.csv")
dftest = pd.concat((pd.read_csv(f,delimiter=';') for f in test_files))
print(dftest)
# Out:
#                        time  P1_B2004  P1_B2016  P1_B3004   P1_B3005  \
# 0       2019-11-04 15:00:00    0.1001    1.5270  395.3508  1120.8154
1_B400B  P1_B4022  P1_FCV01D  ...  P4_ST_FD  \
# 241195   29.4139       0.0   33.9638   33.4685        0.0  ...   -0.0007
# 241196   29.4139       0.0   35.9501   33.4723        0.0  ...   -0.0007
# 241197   29.4139       0.0   36.9430   33.4833        0.0  ...   -0.0003
# 241198   29.4139       0.0   35.9501   33.4837        0.0  ...    0.0008
# 241199   29.4139       0.0   38.9292   33.4811        0.0  ...   -0.0010
#
#         P4_ST_LD  P4_ST_PO  P4_ST_PS  P4_ST_PT01  P4_ST_TT01  attack  \
# ...

# %%
dftrain.shape
# Out:
# (550800, 64)

# %%
dftrain.describe()
# Out:
#             P1_B2004       P1_B2016       P1_B3004       P1_B3005  \
# count  550800.000000  550800.000000  550800.000000  550800.000000
# mean        0.082893       1.196657     406.525602    1087.704990
# std         0.029830       0.183523      18.828682      27.888709
# min         0.029300       0.100179     392.306900     983.115200
# 25%         0.098000       1.057900     395.627100    1083.680700
# 50%         0.098900       1.158300     400.057000    1094.037800
# 75%         0.100600       1.344000     406.061300    1102.893900
# max         0.101900       2.112192     467.296500    1120.815400
#
#             P1_B4002       P1_B4005       P1_B400B       P1_B4022  \
# count  550800.000000  550800.000000  550800.000000  550800.000000
# mean       31.937685      41.455473    1267.102818      35.680649
# std         0.306622      41.060964    1210.146574       0.424571
# min        29.413900       0.000000      19.067300      32.325200
# ...

# %%
dftest.describe()
# Out:
#             P1_B2004       P1_B2016       P1_B3004       P1_B3005  \
# count  444600.000000  444600.000000  444600.000000  444600.000000
# mean        0.072404       1.366993     405.777585    1076.434265
# std         0.034077       0.122947      23.275737      58.129139
# min         0.030000       0.960400     392.330300     926.039400
# 25%         0.031100       1.290800     393.937400    1057.357900
# 50%         0.099500       1.367800     394.446800    1106.358400
# 75%         0.100500       1.444000     401.438700    1114.993300
# max         0.101800       1.879000     472.968000    1120.846200
#
#             P1_B4002       P1_B4005       P1_B400B       P1_B4022  \
# count  444600.000000  444600.000000  444600.000000  444600.000000
# mean       31.861591      42.913070    1312.156581      35.598107
# std         0.501277      40.876923    1204.537513       0.581733
# min        29.413900       0.000000      13.108600      32.351500
# ...

# %%
dftrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 550800 entries, 0 to 241199
# Data columns (total 64 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time        550800 non-null  object
#  1   P1_B2004    550800 non-null  float64
#  2   P1_B2016    550800 non-null  float64
#  3   P1_B3004    550800 non-null  float64
#  4   P1_B3005    550800 non-null  float64
#  5   P1_B4002    550800 non-null  float64
#  6   P1_B4005    550800 non-null  float64
#  7   P1_B400B    550800 non-null  float64
#  8   P1_B4022    550800 non-null  float64
#  9   P1_FCV01D   550800 non-null  float64
#  10  P1_FCV01Z   550800 non-null  float64
#  11  P1_FCV02D   550800 non-null  float64
#  12  P1_FCV02Z   550800 non-null  float64
#  13  P1_FCV03D   550800 non-null  float64
#  14  P1_FCV03Z   550800 non-null  float64
#  15  P1_FT01     550800 non-null  float64
#  16  P1_FT01Z    550800 non-null  float64
#  17  P1_FT02     550800 non-null  float64
# ...

# %%
dftrain.isnull().sum()
# Out:
# time          0
# P1_B2004      0
# P1_B2016      0
# P1_B3004      0
# P1_B3005      0
#              ..
# P4_ST_TT01    0
# attack        0
# attack_P1     0
# attack_P2     0
# attack_P3     0
# Length: 64, dtype: int64

# %%
dftrain.duplicated().sum()
# Out:
# 0

# %%
dftrain.isnull().sum()/len(dftrain)*100
# Out:
# time          0.0
# P1_B2004      0.0
# P1_B2016      0.0
# P1_B3004      0.0
# P1_B3005      0.0
#              ...
# P4_ST_TT01    0.0
# attack        0.0
# attack_P1     0.0
# attack_P2     0.0
# attack_P3     0.0
# Length: 64, dtype: float64

# %%
dfst=dftest.nunique().reset_index()
dfst.columns = ['feature','number Of unique']
dfst[dfst['number Of unique']==1]
# Out:
#       feature  number Of unique
# 33    P2_Auto                 1
# 34    P2_Emgy                 1
# 35      P2_On                 1
# 36    P2_SD01                 1
# 38  P2_TripEx                 1
# 46      P3_LH                 1
# 47      P3_LL                 1
# 52   P4_HT_PS                 1

# %%
dfs=dftrain.nunique().reset_index()
dfs.columns = ['feature','number Of unique']
dfs[dfs['number Of unique']==1]
# Out:
#       feature  number Of unique
# 26  P1_PCV02D                 1
# 33    P2_Auto                 1
# 34    P2_Emgy                 1
# 35      P2_On                 1
# 38  P2_TripEx                 1
# 46      P3_LH                 1
# 47      P3_LL                 1
# 52   P4_HT_PS                 1
# 62  attack_P2                 1
# 63  attack_P3                 1

# %% [markdown]
# ### Data visualization

# %%
dftrain.hist(figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f07de367810>,
# ...
#       dtype=object)

# %%
sns.boxplot(dftrain["P4_HT_PO"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
corr_matrix = dftrain.corr()

# %%
corr_matrix
# Out:
#             P1_B2004  P1_B2016  P1_B3004  P1_B3005  P1_B4002  P1_B4005  \
# P1_B2004    1.000000 -0.198693  0.110056 -0.129477 -0.106941 -0.015936
# P1_B2016   -0.198693  1.000000  0.180849 -0.189421  0.064371  0.111961
# P1_B3004    0.110056  0.180849  1.000000 -0.012664  0.079402  0.094433
# P1_B3005   -0.129477 -0.189421 -0.012664  1.000000 -0.161104 -0.089874
# P1_B4002   -0.106941  0.064371  0.079402 -0.161104  1.000000  0.208312
# ...              ...       ...       ...       ...       ...       ...
# P4_ST_TT01  0.016220 -0.085958 -0.036664  0.026619  0.157604 -0.500815
# attack      0.022419 -0.078210 -0.017864  0.018812  0.039609  0.008276
# attack_P1   0.022419 -0.078210 -0.017864  0.018812  0.039609  0.008276
# attack_P2        NaN       NaN       NaN       NaN       NaN       NaN
# attack_P3        NaN       NaN       NaN       NaN       NaN       NaN
#
#             P1_B400B  P1_B4022  P1_FCV01D  P1_FCV01Z  ...  P4_ST_FD  P4_ST_LD  \
# ...

# %%
heatmap = sns.heatmap(corr_matrix, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=50)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
dftrain.plot(subplots=True, figsize=(40, 30))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f07dec90e50>,
# ...
#       dtype=object)
